# %%
import pandas as pd

# %% [markdown]
# ### Pandas - Basics

# %%
employee_names = ["Amy White", "Jack Stewart", "Richard Lauderdale", "Sara Johnson"]

# %%
print(employee_names)
# Out:
# ['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson']

# %%
print(type(employee_names))
# Out:
# <class 'list'>

# %%
employee_names_Series = pd.Series(employee_names)

# %%
print(employee_names_Series)
# Out:
# 0             Amy White
# 1          Jack Stewart
# 2    Richard Lauderdale
# 3          Sara Johnson
# dtype: object

# %%
print(type(employee_names_Series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
type(employee_names_Series)
# Out:
# pandas.core.series.Series

# %%
work_experience_yrs = pd.Series([5, 8, 3, 10])
print(work_experience_yrs)
# Out:
# 0     5
# 1     8
# 2     3
# 3    10
# dtype: int64

# %%
import numpy as np

# %%
array_age = np.array([50, 53, 35, 43])
array_1 = array_age
print(array_1)
print(type(array_1))
# Out:
# [50 53 35 43]
# <class 'numpy.ndarray'>

# %%
print(type(array_age))
# Out:
# <class 'numpy.ndarray'>

# %%
series_age = pd.Series(array_age)
print(series_age)
print(type(series_age))
# Out:
# 0    50
# 1    53
# 2    35
# 3    43
# dtype: int32
# <class 'pandas.core.series.Series'>

# %%
work_experience_years = pd.Series([5, 8, 3, 10])
print(work_experience_years)
# Out:
# 0     5
# 1     8
# 2     3
# 3    10
# dtype: int64

# %%
print(work_experience_years.to_numpy())
print(type(work_experience_years.to_numpy()))
print(type(work_experience_years))
# Out:
# [ 5  8  3 10]
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>

# %%
print(work_experience_years.size)
# Out:
# 4

# %%
work_experience_years.name = "Work Experience (Yrs.)"
print(work_experience_years.name)
# Out:
# Work Experience (Yrs.)

# %%
work_experience_years
# Out:
# 0     5
# 1     8
# 2     3
# 3    10
# Name: Work Experience (Yrs.), dtype: int64

# %%
print(work_experience_years)
# Out:
# 0     5
# 1     8
# 2     3
# 3    10
# Name: Work Experience (Yrs.), dtype: int64

# %%
workers_age = {"Amy White": 50, "Jack Stewart": 53, "Richard Lauderdale": 35, "Sara Johnson": 43}
print(workers_age)
# Out:
# {'Amy White': 50, 'Jack Stewart': 53, 'Richard Lauderdale': 35, 'Sara Johnson': 43}

# %%
print(type(workers_age))
# Out:
# <class 'dict'>

# %%
workers_age_series = pd.Series(workers_age)
print(workers_age_series)
# Out:
# Amy White             50
# Jack Stewart          53
# Richard Lauderdale    35
# Sara Johnson          43
# dtype: int64

# %%
type(workers_age_series)
# Out:
# pandas.core.series.Series

# %%
workers_age_series.index
# Out:
# Index(['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson'], dtype='object')

# %%
employees_work_exp = pd.Series({"Martin":8, "George": 5})
print(employees_work_exp)
# Out:
# Martin    8
# George    5
# dtype: int64

# %%
employees_work_exp.name = "workers work experience"
print(employees_work_exp)
# Out:
# Martin    8
# George    5
# Name: workers work experience, dtype: int64

# %%
print(employees_work_exp.index)
# Out:
# Index(['Martin', 'George'], dtype='object')

# %%
print(type(employees_work_exp.index[0]))
# Out:
# <class 'str'>

# %%
series_age = pd.Series([44, 54, 65, 35])
print(series_age)
# Out:
# 0    44
# 1    54
# 2    65
# 3    35
# dtype: int64

# %%
print(series_age.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
employees_work_exp = pd.Series({
'Amy White'   : 3,
'Jack Stewart'   : 5,
'Richard Lauderdale'  : 4.5,
'Sara Johnson'  : 22,
'Patrick Adams' : 28,
'Jessica Baker'  : 14,
'Peter Hunt'   : 4,
'Daniel Lloyd'  : 6,
'John Owen'   : 1.5,
'Jennifer Phillips'  : 10,
'Courtney Rogers'   : 4.5,
'Anne Robinson'  : 2,
})

# %%
print(employees_work_exp)
# Out:
# Amy White              3.0
# Jack Stewart           5.0
# Richard Lauderdale     4.5
# Sara Johnson          22.0
# Patrick Adams         28.0
# Jessica Baker         14.0
# Peter Hunt             4.0
# Daniel Lloyd           6.0
# John Owen              1.5
# Jennifer Phillips     10.0
# Courtney Rogers        4.5
# Anne Robinson          2.0
# dtype: float64

# %%
print(employees_work_exp.head(5))
# Out:
# Amy White              3.0
# Jack Stewart           5.0
# Richard Lauderdale     4.5
# Sara Johnson          22.0
# Patrick Adams         28.0
# dtype: float64

# %%
print(employees_work_exp.values.astype(int))
# Out:
# [ 3  5  4 22 28 14  4  6  1 10  4  2]

# %%
print(employees_work_exp.tail(4))
# Out:
# John Owen             1.5
# Jennifer Phillips    10.0
# Courtney Rogers       4.5
# Anne Robinson         2.0
# dtype: float64

# %%
print(employees_work_exp.astype(dtype = np.float64).nlargest(10))
# Out:
# Patrick Adams         28.0
# Sara Johnson          22.0
# Jessica Baker         14.0
# Jennifer Phillips     10.0
# Daniel Lloyd           6.0
# Jack Stewart           5.0
# Richard Lauderdale     4.5
# Courtney Rogers        4.5
# Peter Hunt             4.0
# Amy White              3.0
# dtype: float64

# %%
print(employees_work_exp.astype(dtype = np.int16).nlargest(10))
# Out:
# Patrick Adams         28
# Sara Johnson          22
# Jessica Baker         14
# Jennifer Phillips     10
# Daniel Lloyd           6
# Jack Stewart           5
# Richard Lauderdale     4
# Peter Hunt             4
# Courtney Rogers        4
# Amy White              3
# dtype: int16

# %% [markdown]
# ##### Data Frames

# %%
name_list = ['Amy White','Jack Stewart','Richard Lauderdale','Sara Johnson']
Age_list = [50, 53, 35, 43]
Exp_list = [5, 8, 3, 10]

data = {'Name': name_list, 'Age': Age_list, 'Working Experience (Yrs.)': Exp_list}

df = pd.DataFrame(data)
df
# Out:
#                  Name  Age  Working Experience (Yrs.)
# 0           Amy White   50                          5
# 1        Jack Stewart   53                          8
# 2  Richard Lauderdale   35                          3
# 3        Sara Johnson   43                         10

# %%
data = [{'Name': 'Amy White', 'Age': 50, 'Working Experience (Yrs.)': 5},
        {'Name': 'Jack Stewart', 'Age': 53, 'Working Experience (Yrs.)': 8},
        {'Name': 'Richard Lauderdale', 'Age': 35, 'Working Experience (Yrs.)': 3},
        {'Name': 'Sara Johnson', 'Age': 43, 'Working Experience (Yrs.)': 10}]

df = pd.DataFrame(data)
df
# Out:
#                  Name  Age  Working Experience (Yrs.)
# 0           Amy White   50                          5
# 1        Jack Stewart   53                          8
# 2  Richard Lauderdale   35                          3
# 3        Sara Johnson   43                         10

# %%
names = pd.Series(['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson'])
age = pd.Series([50, 53, 35, 43])
work = pd.Series([5, 8, 3, 10])

data = {'Name': names, 'Age': age, 'Working Experience (Yrs.)': work}

df = pd.DataFrame(data)
df
# Out:
#                  Name  Age  Working Experience (Yrs.)
# 0           Amy White   50                          5
# 1        Jack Stewart   53                          8
# 2  Richard Lauderdale   35                          3
# 3        Sara Johnson   43                         10

# %%
data = [['Amy White', 50, 5], ['Jack Stewart', 53, 35], ['Richard Lauderdale', 35, 3], ['Sara Johnson', 43, 10]]

df = pd.DataFrame(data,columns = ['Name', 'Age', 'Working Experience (Yrs.)'])
df
# Out:
#                  Name  Age  Working Experience (Yrs.)
# 0           Amy White   50                          5
# 1        Jack Stewart   53                         35
# 2  Richard Lauderdale   35                          3
# 3        Sara Johnson   43                         10

# %%
print(data)
print(type(data))
# Out:
# [['Amy White', 50, 5], ['Jack Stewart', 53, 35], ['Richard Lauderdale', 35, 3], ['Sara Johnson', 43, 10]]
# <class 'list'>

# %%
data = {
    "Name":['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson'], 
    "Age":[50, 53, 35, 43], 
    "Working Experience (Yrs.)":[5,8,3,10]}

# %%
print(data)
# Out:
# {'Name': ['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson'], 'Age': [50, 53, 35, 43], 'Working Experience (Yrs.)': [5, 8, 3, 10]}

# %%
df = pd.DataFrame(data, index = [1, 2, 3, 4])
df
# Out:
#                  Name  Age  Working Experience (Yrs.)
# 1           Amy White   50                          5
# 2        Jack Stewart   53                          8
# 3  Richard Lauderdale   35                          3
# 4        Sara Johnson   43                         10

# %%
filename = 'source.txt'
file = open(filename, mode = 'r')
content = file.read()
file.close()
print(content)
# Out:
# This is the simplest plain text file!

# %%
filename = 'source.txt'

with open(filename, mode = 'r') as file:
    text = file.read()
    print("Is file closed: ", file.closed)

print("Is file closed: ", file.closed)
print(text)
# Out:
# Is file closed:  False
# Is file closed:  True
# This is the simplest plain text file!

# %%
filename = 'source.txt'
 
file = open(filename, 'r')
text = file.read()
print("Is file closed: ",file.closed) 
file.close()
print("Is file closed: ",file.closed)  
print(text)
# Out:
# Is file closed:  False
# Is file closed:  True
# This is the simplest plain text file!

# %%
filename='source.txt'
file = open(filename, mode = 'r')
text = file.read()

with open(filename, mode = 'r') as out_file:
    out_file.read()
print(text)
print(out_file)
# Out:
# This is the simplest plain text file!
#
# <_io.TextIOWrapper name='source.txt' mode='r' encoding='cp1252'>

# %%
filename='source.txt'
with open(filename, mode = 'w') as out_file:
    out_file.write("It is not so simple anymore!")

print(out_file)
# Out:
# <_io.TextIOWrapper name='source.txt' mode='w' encoding='cp1252'>

# %%
filename='source.txt'
with open(filename, mode = 'w') as out_file:
    out_file.write("It is not so simple anymore!")

file = open(filename, 'r')
text = file.read()
file.close
print(text)
# Out:
# It is not so simple anymore!

# %%
filename='source.txt'

with open(filename, mode = 'w') as out_file:
    out_file.write("It is not so simple anymore!")

with open(filename, mode = 'r') as new_text:
    print(new_text.read())
# Out:
# It is not so simple anymore!

# %%
filename = "Lending-company.csv"
with open(filename, mode = 'r') as file:
    text = file.read()

print(type(text))
# Out:
# <class 'str'>

# %%
import pandas as pd
df = pd.read_csv("Lending-company.csv")
print(df)
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
filename = "Lending-company.csv"
my_csv_data = pd.read_csv(filename)
print(my_csv_data)
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
import pandas as pd
filename = "Lending-company.csv"
my_csv_data = pd.read_csv(filename, index_col="LoanID")
my_csv_data
# Out:
#            StringID    Product CustomerGender     Location    Region  \
# LoanID
# 1          LoanID_1  Product B         Female   Location 3  Region 2
# 2          LoanID_2  Product D         Female   Location 6  Region 6
# 3          LoanID_3  Product B           Male   Location 8  Region 3
# 4          LoanID_4  Product A           Male  Location 26  Region 2
# 5          LoanID_5  Product B         Female  Location 34  Region 3
# ...             ...        ...            ...          ...       ...
# 1039    LoanID_1039  Product B           Male  Location 73  Region 6
# 1040    LoanID_1040  Product A           Male  Location 82  Region 1
# 1041    LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1042    LoanID_1042  Product B         Female  Location 26  Region 6
# 1043    LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#         TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# LoanID
# ...

# %%
np.set_printoptions(suppress = True, linewidth = 100, precision=2)

# %%
my_csv_data
# Out:
#            StringID    Product CustomerGender     Location    Region  \
# LoanID
# 1          LoanID_1  Product B         Female   Location 3  Region 2
# 2          LoanID_2  Product D         Female   Location 6  Region 6
# 3          LoanID_3  Product B           Male   Location 8  Region 3
# 4          LoanID_4  Product A           Male  Location 26  Region 2
# 5          LoanID_5  Product B         Female  Location 34  Region 3
# ...             ...        ...            ...          ...       ...
# 1039    LoanID_1039  Product B           Male  Location 73  Region 6
# 1040    LoanID_1040  Product A           Male  Location 82  Region 1
# 1041    LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1042    LoanID_1042  Product B         Female  Location 26  Region 6
# 1043    LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#         TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# LoanID
# ...

# %%
import numpy as np

np.set_printoptions(suppress = True, linewidth = 150)
lending_co_TP = np.loadtxt("Lending-Company-Total-Price-100.csv", delimiter = ',', dtype=np.dtype(str))
print(lending_co_TP)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600']
#  ...
#  ['413' 'id_413' 'Product B' ... 'Location 135' 'Region 1' '16600']
#  ['414' 'id_414' 'Product C' ... 'Location 200' 'Region 6' '15600']
#  ['415' 'id_415' 'Product A' ... 'Location 8' 'Region 2' '22250']]

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price-100.csv", delimiter=",")
print(lending_co_TP)
# Out:
# [[   nan    nan    nan ...    nan    nan    nan]
#  [    1.    nan    nan ...    nan    nan 16600.]
#  [    2.    nan    nan ...    nan    nan 16600.]
#  ...
#  [  413.    nan    nan ...    nan    nan 16600.]
#  [  414.    nan    nan ...    nan    nan 15600.]
#  [  415.    nan    nan ...    nan    nan 22250.]]

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price-100.csv"
                              , delimiter=","
                              , dtype=str
                              , skip_header=1
                              , skip_footer=15
                              , usecols = (1, 2, 4)
                             )
print(lending_co_TP)
# Out:
# [['id_1' 'Product B' 'Location 2']
#  ['id_2' 'Product B' 'Location 3']
#  ['id_3' 'Product C' 'Location 5']
#  ...
#  ['id_398' 'Product A' 'Location 29']
#  ['id_399' 'Product B' 'Location 73']
#  ['id_400' 'Product B' 'Location 53']]

# %%
import numpy as np

lending_co_TP = np.genfromtxt("Lending-Company-Total-Price-100.csv"
                              , delimiter = ","
                              , dtype = str
                              , skip_header = 1
                              , skip_footer = 15
                              , usecols = (1, 2, 4)
                              , comments = "#"
                              , converters = None
                              , missing_values = None
                              , excludelist = None
                              , deletechars = " ()*+,-./:;<=>?@[\\]^{|}~"
                              , replace_space = "_"
                              , autostrip = True
                             )
print(lending_co_TP)
# Out:
# [['id_1' 'Product B' 'Location 2']
#  ['id_2' 'Product B' 'Location 3']
#  ['id_3' 'Product C' 'Location 5']
#  ...
#  ['id_398' 'Product A' 'Location 29']
#  ['id_399' 'Product B' 'Location 73']
#  ['id_400' 'Product B' 'Location 53']]

# %%
import numpy as np

lending_co_TP = np.genfromtxt("Lending-Company-Total-Price-100.csv"
                              , delimiter = ","
                              , dtype = str
                              , skip_header = 1
                              , usecols = (0, -1)
                             )
print(lending_co_TP)
# Out:
# [['1' '16600']
#  ['2' '16600']
#  ['3' '15600']
#  ['4' '16600']
#  ['5' '20250']
#  ['6' '']
#  ['7' '20250']
#  ['8' '16600']
#  ['9' '22250']
#  ['10' '20250']
#  ['11' '16600']
#  ['12' '20250']
#  ['13' '16600']
#  ['14' '20750']
#  ['15' '22250']
#  ['16' '16600']
#  ['17' '22250']
#  ['18' '16600']
#  ['19' '16600']
#  ['20' '54625']
#  ['21' '16600']
#  ['22' '22250']
#  ['23' '19250']
#  ['24' '15600']
#  ['25' '20250']
#  ['26' '22250']
#  ['27' '19250']
#  ['28' '69225']
#  ['29' '20250']
#  ['30' '16600']
#  ['31' '16600']
#  ['32' '16600']
#  ['33' '19250']
#  ['34' '16600']
#  ['35' '19250']
#  ['36' '16600']
#  ['37' '16600']
#  ['38' '16600']
#  ['39' '15600']
#  ['40' '16600']
#  ['41' '16600']
#  ['42' '16600']
#  ['43' '19250']
#  ['44' '15600']
#  ['45' '19250']
#  ['46' '16600']
#  ['47' '16600']
#  ['48' '16600']
#  ['49' '20250']
#  ['50' '22250']
#  ['51' '16600']
#  ['52' '20250']
#  ['53' '20250']
#  ['54' '16600']
#  ['55' '16600']
#  ['56' '16600']
# ...

# %%
lending_co_TP = np.genfromtxt("Lending-Company-Total-Price-100.csv"
                              , delimiter = ","
                              , dtype = float
                              , skip_header = 1
                              , usecols = (0, -1)
                             )
print(lending_co_TP)
# Out:
# [[    1. 16600.]
#  [    2. 16600.]
#  [    3. 15600.]
#  [    4. 16600.]
#  [    5. 20250.]
#  [    6.    nan]
#  [    7. 20250.]
#  [    8. 16600.]
#  [    9. 22250.]
#  [   10. 20250.]
#  [   11. 16600.]
#  [   12. 20250.]
#  [   13. 16600.]
#  [   14. 20750.]
#  [   15. 22250.]
#  [   16. 16600.]
#  [   17. 22250.]
#  [   18. 16600.]
#  [   19. 16600.]
#  [   20. 54625.]
#  [   21. 16600.]
#  [   22. 22250.]
#  [   23. 19250.]
#  [   24. 15600.]
#  [   25. 20250.]
#  [   26. 22250.]
#  [   27. 19250.]
#  [   28. 69225.]
#  [   29. 20250.]
#  [   30. 16600.]
#  [   31. 16600.]
#  [   32. 16600.]
#  [   33. 19250.]
#  [   34. 16600.]
#  [   35. 19250.]
#  [   36. 16600.]
#  [   37. 16600.]
#  [   38. 16600.]
#  [   39. 15600.]
#  [   40. 16600.]
#  [   41. 16600.]
#  [   42. 16600.]
#  [   43. 19250.]
#  [   44. 15600.]
#  [   45. 19250.]
#  [   46. 16600.]
#  [   47. 16600.]
#  [   48. 16600.]
#  [   49. 20250.]
#  [   50. 22250.]
#  [   51. 16600.]
#  [   52. 20250.]
# ...

# %%
data = {'ProductName':['Product A', 'Product B', 'Product C'], 'ProductPrice':[22250, 16600, 12500]}
product_IDs = ['A', 'B', 'C']

df = pd.DataFrame(data, index=product_IDs)
df
# Out:
#   ProductName  ProductPrice
# A   Product A         22250
# B   Product B         16600
# C   Product C         12500

# %%
prices_per_product = '{"Product A": 22250, "Product B" : 16600, "Product C":15600}'

print(prices_per_product)
print(type(prices_per_product))
# Out:
# {"Product A": 22250, "Product B" : 16600, "Product C":15600}
# <class 'str'>

# %%
import json

# %%
print(json.loads(prices_per_product))
# Out:
# {'Product A': 22250, 'Product B': 16600, 'Product C': 15600}

# %%
prices_per_product = '{"Product A": 22250, "Product B" : 16600, "Product C":15600}'

print(type(json.loads(prices_per_product)))
# Out:
# <class 'dict'>

# %%
new_csv_data = pd.read_json("Lending-company-100.json")
print(new_csv_data)
# Out:
#       Loan ID String_ID    Product CustomerGender      Location    Region  \
# 0           1      id_1  Product B           Male    Location 2  Region 2
# 1           2      id_2  Product B           Male    Location 3  Region 3
# 2           3      id_3  Product C         Female    Location 5  Region 5
# 3           4      id_4  Product B           Male    Location 6  Region 1
# 4           5      id_5  Product D         Female    Location 7  Region 2
# ...       ...       ...        ...            ...           ...       ...
# 1038     1039   id_1039  Product B         Female   Location 39  Region 6
# 1039     1040   id_1040  Product B           Male   Location 50  Region 1
# 1040     1041   id_1041  Product B           Male   Location 23  Region 4
# 1041     1042   id_1042  Product C   NotSpecified   Location 52  Region 6
# 1042     1043   id_1043  Product B         Female  Location 142  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDays  AmountPaid30  \
# ...

# %%
print(type(new_csv_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
location_data = pd.read_csv("Lending-company-single-column-data.csv")
print(location_data)
# Out:
#      LoanID,StringID,Product,CustomerGender,Location,Region,TotalPrice,StartDate,Deposit,DailyRate,TotalDaysYr,AmtPaid36,AmtPaid60,AmtPaid360,LoanStatus
# 0     1,LoanID_1,Product B,Female,Location 3,Region ...
# 1     2,LoanID_2,Product D,Female,Location 6,Region ...
# 2     3,LoanID_3,Product B,Male,Location 8,Region 3,...
# 3     4,LoanID_4,Product A,Male,Location 26,Region 2...
# 4     5,LoanID_5,Product B,Female,Location 34,Region...
# ...                                                 ...
# 1038  1039,LoanID_1039,Product B,Male,Location 73,Re...
# 1039  1040,LoanID_1040,Product A,Male,Location 82,Re...
# 1040  1041,LoanID_1041,Product A,NotSpecified,Locati...
# 1041  1042,LoanID_1042,Product B,Female,Location 26,...
# 1042  1043,LoanID_1043,Product A,NotSpecified,Locati...
#
# [1043 rows x 1 columns]

# %%
location_data = pd.read_csv("Lending-company-single-column-data.csv", usecols =['StringID', 'Location', 'Region'], index_col = 'StringID')
print(location_data.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 location_data = pd.read_csv("Lending-company-single-column-data.csv", usecols =['StringID', 'Location', 'Region'], index_col = 'StringID')
#       2 print(location_data.head())
#
# ...

# %%
import pandas as pd

# Read the CSV (single column)
df = pd.read_csv("Lending-company-single-column-data.csv", header=None)

# Split the single column into multiple columns
df = df[0].str.split(",", expand=True)

# First row becomes column names
df.columns = df.iloc[0]

# Drop the header row from data
df = df.drop(index=0)

# Select specific columns and set index
df = df[['StringID', 'Location', 'Region']].set_index('StringID')

print(df.head())
# Out:
# 0            Location    Region
# StringID
# LoanID_1   Location 3  Region 2
# LoanID_2   Location 6  Region 6
# LoanID_3   Location 8  Region 3
# LoanID_4  Location 26  Region 2
# LoanID_5  Location 34  Region 3

# %%
my_csv_data = pd.read_csv("Lending-company-single-column-data.csv")
print(my_csv_data.head())
# Out:
#   LoanID,StringID,Product,CustomerGender,Location,Region,TotalPrice,StartDate,Deposit,DailyRate,TotalDaysYr,AmtPaid36,AmtPaid60,AmtPaid360,LoanStatus
# 0  1,LoanID_1,Product B,Female,Location 3,Region ...
# 1  2,LoanID_2,Product D,Female,Location 6,Region ...
# 2  3,LoanID_3,Product B,Male,Location 8,Region 3,...
# 3  4,LoanID_4,Product A,Male,Location 26,Region 2...
# 4  5,LoanID_5,Product B,Female,Location 34,Region...

# %%
filename = 'Lending-company-single-column-data.csv'
my_csv_data = pd.read_csv(filename, sep = '\,', engine = 'python')
 
print(my_csv_data.head())
# Out:
#   "LoanID  StringID    Product CustomerGender     Location    Region  \
# 0      "1  LoanID_1  Product B         Female   Location 3  Region 2
# 1      "2  LoanID_2  Product D         Female   Location 6  Region 6
# 2      "3  LoanID_3  Product B           Male   Location 8  Region 3
# 3      "4  LoanID_4  Product A           Male  Location 26  Region 2
# 4      "5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus"
# 0       4166       14621     Active"
# 1       4096       16041     Active"
# ...

# %%
filename = 'Lending-company-single-column-data.csv'
my_csv_data = pd.read_csv(filename, delimiter = '\,', engine = 'python')
 
print(my_csv_data.head())
# Out:
#   "LoanID  StringID    Product CustomerGender     Location    Region  \
# 0      "1  LoanID_1  Product B         Female   Location 3  Region 2
# 1      "2  LoanID_2  Product D         Female   Location 6  Region 6
# 2      "3  LoanID_3  Product B           Male   Location 8  Region 3
# 3      "4  LoanID_4  Product A           Male  Location 26  Region 2
# 4      "5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus"
# 0       4166       14621     Active"
# 1       4096       16041     Active"
# ...

# %%
my_df = pd.read_csv("Lending-company.csv")
print(my_df.head(5))
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
print(type(my_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_usecols = pd.read_csv("Lending-company.csv", usecols = ['Product'])
print(df_usecols.head(5))
# Out:
#      Product
# 0  Product B
# 1  Product D
# 2  Product B
# 3  Product A
# 4  Product B

# %%
print(type(df_usecols))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_single_col = pd.read_csv("Customer-Gender.csv")
print(df_single_col.head(5))
# Out:
#   CustomerGender
# 0         Female
# 1         Female
# 2           Male
# 3           Male
# 4         Female

# %%
print(type(df_single_col))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = pd.read_csv("Lending-company.csv")
df_squeeze = data.squeeze()
print(type(data))
print(df_squeeze.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# ...

# %%
data = pd.read_csv("Lending-company.csv", usecols=['Product'])
product_data = data.squeeze()
print(product_data)
# Out:
# 0       Product B
# 1       Product D
# 2       Product B
# 3       Product A
# 4       Product B
#           ...
# 1038    Product B
# 1039    Product A
# 1040    Product A
# 1041    Product B
# 1042    Product A
# Name: Product, Length: 1043, dtype: object

# %%
data = pd.read_csv("Lending-company.csv", usecols=['Product'])
product_data = data.squeeze("columns")
print(product_data)
# Out:
# 0       Product B
# 1       Product D
# 2       Product B
# 3       Product A
# 4       Product B
#           ...
# 1038    Product B
# 1039    Product A
# 1040    Product A
# 1041    Product B
# 1042    Product A
# Name: Product, Length: 1043, dtype: object

# %%
data = pd.read_csv("Lending-company.csv", usecols = ['Product'])
product_data = data.squeeze(1)
print(product_data)
# Out:
# 0       Product B
# 1       Product D
# 2       Product B
# 3       Product A
# 4       Product B
#           ...
# 1038    Product B
# 1039    Product A
# 1040    Product A
# 1041    Product B
# 1042    Product A
# Name: Product, Length: 1043, dtype: object

# %%
product_data = data.squeeze(axis = 1)
print(product_data)
# Out:
# 0       Product B
# 1       Product D
# 2       Product B
# 3       Product A
# 4       Product B
#           ...
# 1038    Product B
# 1039    Product A
# 1040    Product A
# 1041    Product B
# 1042    Product A
# Name: Product, Length: 1043, dtype: object

# %%
df_single_col = pd.read_csv("Customer-Gender.csv")
selected_data = df_single_col.squeeze()
print(selected_data.head(5))
# Out:
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# Name: CustomerGender, dtype: object

# %%
import os, inspect

if '__file__' not in locals():
    fx = inspect.getframeinfo(inspect.currentframe())[0]
else:
    fx = __file__  
    
os_dir = os.path.dirname(os.path.abspath(fx))

print(os_dir)
# Out:
# C:\Users\Karthik\AppData\Local\Temp\ipykernel_9268

# %%
import pandas as pd
filename = 'Lending-company.csv'
my_data = pd.read_csv(filename)
my_data.to_csv('my-csv-file.csv')

# %%
my_data.to_json('my-json-file.json')

# %%
import numpy as np
np.set_printoptions(suppress = True, linewidth = 150)

lending_co_saving = np.genfromtxt("Lending-Company-Saving-100.csv", 
                                    delimiter = ',', 
                                    dtype = str)

lending_co_total_price = np.genfromtxt("Lending-Company-Total-Price-100.csv",
                                    delimiter = ',', 
                                    dtype = str)

# %%
print(lending_co_saving)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
np.save('Saving-Exercise-1', lending_co_saving)
np.save('Saving-Exercise-2', lending_co_total_price)

# %%
np.savez("Saving-Exercise-3", saving = lending_co_saving, total_price = lending_co_total_price)

# %%
lending_co_saving = np.genfromtxt("Lending-Company-Saving-100.csv", 
                                    delimiter = ',', 
                                    dtype = str)

np.savetxt("Saving-Exercise-4.csv", lending_co_saving, fmt = '%s', delimiter=',')

# %%
region_data = pd.read_csv('Region.csv').squeeze(1)
region_data.head()
# Out:
# 0    Region 2
# 1    Region 6
# 2    Region 3
# 3    Region 2
# 4    Region 3
# Name: Region, dtype: object

# %%
data = pd.read_csv('Region.csv').squeeze("columns")
region_data = data.copy()

print(type(region_data))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(region_data.describe())
# Out:
# count         1042
# unique          18
# top       Region 6
# freq           326
# Name: Region, dtype: object

# %%
print(region_data.count())
# Out:
# 1042

# %%
print(len(region_data.unique()))
# Out:
# 18

# %%
print(region_data.unique())
# Out:
# ['Region 2' 'Region 6' 'Region 3' 'Region 1' 'Region 5' 'Region 9' 'Region 7' 'Region 4' 'Region 12' 'Region 16' 'Region 8' 'Region 10' 'Region 13'
#  'Region 15' 'Region 11' 'Region 14' 'Region 17' 'Region 18']

# %%
print(region_data.head())
# Out:
# 0    Region 2
# 1    Region 6
# 2    Region 3
# 3    Region 2
# 4    Region 3
# Name: Region, dtype: object

# %%
print(region_data.sort_values())
# Out:
# 462    Region 1
# 347    Region 1
# 609    Region 1
# 610    Region 1
# 339    Region 1
#          ...
# 536    Region 9
# 450    Region 9
# 8      Region 9
# 842    Region 9
# 940    Region 9
# Name: Region, Length: 1042, dtype: object

# %%
print(region_data.sort_values(ascending=True))
# Out:
# 462    Region 1
# 347    Region 1
# 609    Region 1
# 610    Region 1
# 339    Region 1
#          ...
# 536    Region 9
# 450    Region 9
# 8      Region 9
# 842    Region 9
# 940    Region 9
# Name: Region, Length: 1042, dtype: object

# %%
print(region_data.sort_values(ascending=False))
# Out:
# 450    Region 9
# 842    Region 9
# 141    Region 9
# 940    Region 9
# 8      Region 9
#          ...
# 569    Region 1
# 892    Region 1
# 558    Region 1
# 557    Region 1
# 309    Region 1
# Name: Region, Length: 1042, dtype: object

# %%
data = pd.read_csv('Region.csv')

region_data = data.copy().squeeze('columns')

print(region_data.head())
# Out:
# 0    Region 2
# 1    Region 6
# 2    Region 3
# 3    Region 2
# 4    Region 3
# Name: Region, dtype: object

# %%
print(region_data.sort_values(ascending = True).head(5))
# Out:
# 462    Region 1
# 347    Region 1
# 609    Region 1
# 610    Region 1
# 339    Region 1
# Name: Region, dtype: object

# %%
print(region_data.head(5).sort_values(ascending = True))
# Out:
# 0    Region 2
# 3    Region 2
# 2    Region 3
# 4    Region 3
# 1    Region 6
# Name: Region, dtype: object

# %%
print(region_data.sort_values(ascending = False).tail(5))
# Out:
# 569    Region 1
# 892    Region 1
# 558    Region 1
# 557    Region 1
# 309    Region 1
# Name: Region, dtype: object

# %%
print(region_data.tail(5).sort_values(ascending = False))
# Out:
# 1037    Region 6
# 1040    Region 6
# 1041    Region 6
# 1039    Region 4
# 1038    Region 1
# Name: Region, dtype: object

# %%
emp_birth_date = pd.Series({'No_0001': '1963-08-02','No_0002': '1964-06-13','No_0003': '1989-12-04', 'No_0004': '1996-04-08'})

print(emp_birth_date)
# Out:
# No_0001    1963-08-02
# No_0002    1964-06-13
# No_0003    1989-12-04
# No_0004    1996-04-08
# dtype: object

# %%
print(emp_birth_date.index)
# Out:
# Index(['No_0001', 'No_0002', 'No_0003', 'No_0004'], dtype='object')

# %%
print(emp_birth_date.index.to_numpy())
# Out:
# ['No_0001' 'No_0002' 'No_0003' 'No_0004']

# %%
data = pd.read_csv('Region.csv')

region_data = data.copy().squeeze("columns")

print(region_data.head())
# Out:
# 0    Region 2
# 1    Region 6
# 2    Region 3
# 3    Region 2
# 4    Region 3
# Name: Region, dtype: object

# %%
data = pd.read_csv('Region.csv').squeeze("columns")
region_data = data.copy().sort_values(ascending = False)
print(region_data)
# Out:
# 450    Region 9
# 842    Region 9
# 141    Region 9
# 940    Region 9
# 8      Region 9
#          ...
# 569    Region 1
# 892    Region 1
# 558    Region 1
# 557    Region 1
# 309    Region 1
# Name: Region, Length: 1042, dtype: object

# %%
data = pd.read_csv('Region.csv').squeeze("columns")
region_data = data.copy()
region_data = region_data.sort_values(ascending=False)

print(region_data.sort_index())
# Out:
# 0       Region 2
# 1       Region 6
# 2       Region 3
# 3       Region 2
# 4       Region 3
#           ...
# 1037    Region 6
# 1038    Region 1
# 1039    Region 4
# 1040    Region 6
# 1041    Region 6
# Name: Region, Length: 1042, dtype: object

# %%
region_data = data.copy()
region_data = region_data.sort_values(ascending=False)

print(region_data.sort_index(ascending=False))
# Out:
# 1041    Region 6
# 1040    Region 6
# 1039    Region 4
# 1038    Region 1
# 1037    Region 6
#           ...
# 4       Region 3
# 3       Region 2
# 2       Region 3
# 1       Region 6
# 0       Region 2
# Name: Region, Length: 1042, dtype: object

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 2000)
pd.set_option('display.max_rows', None)

# %%
array_a = np.array([[1000, 50, 78.45],[700, 112, 35.5]])
print(array_a)
# Out:
# [[1000.     50.     78.45]
#  [ 700.    112.     35.5 ]]

# %%
df_columns =  ['No. of Employees','Avg. Annual Revenue ($)','Share price ($)']
df_index = ['Company A','Company B']
company_statistics = pd.DataFrame(array_a, columns = df_columns, index = df_index)

# %%
company_statistics
# Out:
#            No. of Employees  Avg. Annual Revenue ($)  Share price ($)
# Company A            1000.0                     50.0            78.45
# Company B             700.0                    112.0            35.50

# %%
data = pd.read_csv('Sales-products-100.csv')
sales_products_data = data.copy()
print(sales_products_data.head(5))
# Out:
#      SaleID RetailerCountry OrderMethod   RetailerType           ProductLine   ProductType                    Product    Year  Quarter   Revenue  Quantity  GrossMargin
# 0  SaleID_1   United States         Fax  Outdoors Shop  Personal Accessories  Cooking Gear  TrailChef Deluxe Cook Set  2018.0  Q1 2018  59728.66     491.0     0.357548
# 1  SaleID_2   United States         Fax  Outdoors Shop      Sports Equipment  Cooking Gear     TrailChef Double Flame  2018.0  Q1 2018  36050.32     254.0     0.484274
# 2  SaleID_3   United States         Fax  Outdoors Shop                   NaN         Tents                  Star Dome  2018.0  Q1 2018  90040.48     149.0          NaN
# 3  SaleID_4   United States         Fax  Outdoors Shop                   NaN         Tents               Star Gazer 2  2018.0  Q1 2018       NaN     305.0     0.292938
# ...

# %%
print(type(sales_products_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(sales_products_data.tail(5))
# Out:
#            SaleID RetailerCountry  OrderMethod   RetailerType           ProductLine           ProductType                Product    Year  Quarter   Revenue  Quantity  GrossMargin
# 1271  SaleID_1272           Spain  Sales visit  Outdoors Shop  Personal Accessories                  Rope          Husky Rope 60  2020.0  Q3 2020  30916.50     173.0     0.298114
# 1272  SaleID_1273           Spain  Sales visit  Outdoors Shop    Outdoor Protection  Climbing Accessories  Firefly Climbing Lamp  2020.0  Q3 2020   7536.29     193.0     0.445287
# 1273  SaleID_1274           Spain  Sales visit  Outdoors Shop  Personal Accessories  Climbing Accessories        Firefly Charger  2020.0  Q3 2020  12306.48     238.0     0.568420
# 1274  SaleID_1275           Spain  Sales visit  Outdoors Shop  Personal Accessories                 Tools            Granite Axe  2020.0  Q3 2020  56499.00    1472.0     0.490667
# ...

# %%
sales_products_data.describe()
# Out:
#               Year        Revenue      Quantity  GrossMargin
# count  1275.000000    1260.000000   1273.000000  1250.000000
# mean   2018.427451   31416.916794    600.657502     0.459638
# std       0.717596   51124.450625    977.723516     0.112575
# min    2018.000000       0.000000      1.000000     0.058709
# 25%    2018.000000    7452.782500    108.000000     0.375364
# 50%    2018.000000   15997.400000    267.000000     0.462960
# 75%    2019.000000   39661.317500    643.000000     0.526765
# max    2020.000000  944436.750000  13758.000000     0.780476

# %%
sales_products_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SaleID           1276 non-null   object
#  1   RetailerCountry  1276 non-null   object
#  2   OrderMethod      1271 non-null   object
#  3   RetailerType     1273 non-null   object
#  4   ProductLine      1273 non-null   object
#  5   ProductType      1273 non-null   object
#  6   Product          1272 non-null   object
#  7   Year             1275 non-null   float64
#  8   Quarter          1276 non-null   object
#  9   Revenue          1260 non-null   float64
#  10  Quantity         1273 non-null   float64
#  11  GrossMargin      1250 non-null   float64
# dtypes: float64(4), object(8)
# memory usage: 119.8+ KB

# %%
sales_products_data.sort_values('Revenue', ascending=False).head(5)
# Out:
#          SaleID RetailerCountry OrderMethod      RetailerType               ProductLine ProductType                       Product    Year  Quarter    Revenue  Quantity  GrossMargin
# 813  SaleID_814   United States         Web   Warehouse Store          Sports Equipment       Tents                  Star Gazer 2  2018.0  Q4 2018  944436.75    1727.0     0.281938
# 811  SaleID_812   United States         Web   Warehouse Store         Camping Equipment       Tents                     Star Lite  2018.0  Q4 2018  726855.88    2091.0     0.280444
# 377  SaleID_378           China       Phone              Mall         Camping Equipment       Woods  Hailstorm Titanium Woods Set  2018.0  Q3 2018  431430.02     363.0     0.432507
# 822  SaleID_823   United States       Other   Warehouse Store  Mountaineering Equipment       Tents                  Star Gazer 2  2018.0  Q4 2018  371235.66     680.0     0.281938
# ...

# %%
print(sales_products_data.index.dtype)
# Out:
# int64

# %%
print(type(sales_products_data.index))
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
print(sales_products_data.columns)
# Out:
# Index(['SaleID', 'RetailerCountry', 'OrderMethod', 'RetailerType', 'ProductLine', 'ProductType', 'Product', 'Year', 'Quarter', 'Revenue', 'Quantity', 'GrossMargin'], dtype='object')

# %%
new_column_names = ['SaleID', 'Country', 'OrderMethod', 'Retailer', 'Line', 'Type', 'Product', 'YearOfSales', 'Quarter', 'Revenue', 'Quantity', 'Margin']

# %%
new_column_names
# Out:
# ['SaleID',
#  'Country',
#  'OrderMethod',
#  'Retailer',
#  'Line',
#  'Type',
#  'Product',
#  'YearOfSales',
#  'Quarter',
#  'Revenue',
#  'Quantity',
#  'Margin']

# %%
print(sales_products_data.columns)
# Out:
# Index(['SaleID', 'RetailerCountry', 'OrderMethod', 'RetailerType', 'ProductLine', 'ProductType', 'Product', 'Year', 'Quarter', 'Revenue', 'Quantity', 'GrossMargin'], dtype='object')

# %%
df = pd.DataFrame(sales_products_data, columns=new_column_names)
print(df)
# Out:
#            SaleID  Country  OrderMethod  Retailer  Line  Type                            Product  YearOfSales  Quarter    Revenue  Quantity  Margin
# 0        SaleID_1      NaN          Fax       NaN   NaN   NaN          TrailChef Deluxe Cook Set          NaN  Q1 2018   59728.66     491.0     NaN
# 1        SaleID_2      NaN          Fax       NaN   NaN   NaN             TrailChef Double Flame          NaN  Q1 2018   36050.32     254.0     NaN
# 2        SaleID_3      NaN          Fax       NaN   NaN   NaN                          Star Dome          NaN  Q1 2018   90040.48     149.0     NaN
# 3        SaleID_4      NaN          Fax       NaN   NaN   NaN                       Star Gazer 2          NaN  Q1 2018        NaN     305.0     NaN
# 4        SaleID_5      NaN          NaN       NaN   NaN   NaN                 Compact Relief Kit          NaN  Q1 2018        NaN     182.0     NaN
# ...

# %%
sales_products_data
# Out:
#            SaleID RetailerCountry  OrderMethod       RetailerType               ProductLine           ProductType                            Product    Year  Quarter    Revenue  Quantity  GrossMargin
# 0        SaleID_1   United States          Fax      Outdoors Shop      Personal Accessories          Cooking Gear          TrailChef Deluxe Cook Set  2018.0  Q1 2018   59728.66     491.0     0.357548
# 1        SaleID_2   United States          Fax      Outdoors Shop          Sports Equipment          Cooking Gear             TrailChef Double Flame  2018.0  Q1 2018   36050.32     254.0     0.484274
# 2        SaleID_3   United States          Fax      Outdoors Shop                       NaN                 Tents                          Star Dome  2018.0  Q1 2018   90040.48     149.0          NaN
# ...

# %%
print(df.axes[1])
# Out:
# Index(['SaleID', 'Country', 'OrderMethod', 'Retailer', 'Line', 'Type', 'Product', 'YearOfSales', 'Quarter', 'Revenue', 'Quantity', 'Margin'], dtype='object')

# %%
print(sales_products_data.axes[1])
# Out:
# Index(['SaleID', 'RetailerCountry', 'OrderMethod', 'RetailerType', 'ProductLine', 'ProductType', 'Product', 'Year', 'Quarter', 'Revenue', 'Quantity', 'GrossMargin'], dtype='object')

# %%
print(sales_products_data.axes[0])
# Out:
# RangeIndex(start=0, stop=1276, step=1)

# %%
print(sales_products_data.dtypes)
# Out:
# SaleID              object
# RetailerCountry     object
# OrderMethod         object
# RetailerType        object
# ProductLine         object
# ProductType         object
# Product             object
# Year               float64
# Quarter             object
# Revenue            float64
# Quantity           float64
# GrossMargin        float64
# dtype: object

# %%
print(sales_products_data.to_numpy())
# Out:
# [['SaleID_1' 'United States' 'Fax' ... 59728.66 491.0 0.35754797]
#  ['SaleID_2' 'United States' 'Fax' ... 36050.32 254.0 0.4842745]
#  ['SaleID_3' 'United States' 'Fax' ... 90040.48 149.0 nan]
#  ...
#  ['SaleID_1274' 'Spain' 'Sales visit' ... 12306.48 238.0 0.56842037]
#  ['SaleID_1275' 'Spain' 'Sales visit' ... 56499.0 1472.0 0.49066667]
#  ['SaleID_1276' 'Spain' 'Sales visit' ... 89427.0 1178.0 0.38689474]]

# %%
print(type(sales_products_data.to_numpy()))
# Out:
# <class 'numpy.ndarray'>

# %%
print(sales_products_data.shape)
# Out:
# (1276, 12)

# %%
print(type(sales_products_data.shape))
# Out:
# <class 'tuple'>

# %%
print(sales_products_data.head(5))
# Out:
#      SaleID RetailerCountry OrderMethod   RetailerType           ProductLine   ProductType                    Product    Year  Quarter   Revenue  Quantity  GrossMargin
# 0  SaleID_1   United States         Fax  Outdoors Shop  Personal Accessories  Cooking Gear  TrailChef Deluxe Cook Set  2018.0  Q1 2018  59728.66     491.0     0.357548
# 1  SaleID_2   United States         Fax  Outdoors Shop      Sports Equipment  Cooking Gear     TrailChef Double Flame  2018.0  Q1 2018  36050.32     254.0     0.484274
# 2  SaleID_3   United States         Fax  Outdoors Shop                   NaN         Tents                  Star Dome  2018.0  Q1 2018  90040.48     149.0          NaN
# 3  SaleID_4   United States         Fax  Outdoors Shop                   NaN         Tents               Star Gazer 2  2018.0  Q1 2018       NaN     305.0     0.292938
# ...

# %%
print(sales_products_data.Product)
# Out:
# 0               TrailChef Deluxe Cook Set
# 1                  TrailChef Double Flame
# 2                               Star Dome
# 3                            Star Gazer 2
# 4                      Compact Relief Kit
# 5                             Aloe Relief
# 6                                Infinity
# 7                                      TX
# 8                                  Legend
# 9                              Sun Shield
# 10                            Aloe Relief
# 11                  Hailstorm Steel Irons
# 12                                 Trendi
# 13                                   Zone
# 14                               Hawk Eye
# 15                              Max Gizmo
# 16                           Pocket Gizmo
# 17                           Opera Vision
# 18                     Hibernator Extreme
# 19                         Husky Rope 200
# 20                Granite Climbing Helmet
# 21                          Husky Harness
# ...

# %%
print(sales_products_data["Product"])
# Out:
# 0               TrailChef Deluxe Cook Set
# 1                  TrailChef Double Flame
# 2                               Star Dome
# 3                            Star Gazer 2
# 4                      Compact Relief Kit
# 5                             Aloe Relief
# 6                                Infinity
# 7                                      TX
# 8                                  Legend
# 9                              Sun Shield
# 10                            Aloe Relief
# 11                  Hailstorm Steel Irons
# 12                                 Trendi
# 13                                   Zone
# 14                               Hawk Eye
# 15                              Max Gizmo
# 16                           Pocket Gizmo
# 17                           Opera Vision
# 18                     Hibernator Extreme
# 19                         Husky Rope 200
# 20                Granite Climbing Helmet
# 21                          Husky Harness
# ...

# %%
print(sales_products_data["Product"].tail())
# Out:
# 1271            Husky Rope 60
# 1272    Firefly Climbing Lamp
# 1273          Firefly Charger
# 1274              Granite Axe
# 1275          Granite Extreme
# Name: Product, dtype: object

# %%
print(sales_products_data.Quarter)
# Out:
# 0       Q1 2018
# 1       Q1 2018
# 2       Q1 2018
# 3       Q1 2018
# 4       Q1 2018
# 5       Q1 2018
# 6       Q1 2018
# 7       Q1 2018
# 8       Q1 2018
# 9       Q1 2018
# 10      Q1 2018
# 11      Q1 2018
# 12      Q1 2018
# 13      Q1 2018
# 14      Q1 2018
# 15      Q1 2018
# 16      Q1 2018
# 17      Q1 2018
# 18      Q1 2018
# 19      Q1 2018
# 20      Q1 2018
# 21      Q1 2018
# 22      Q1 2018
# 23      Q1 2018
# 24      Q1 2018
# 25      Q1 2018
# 26      Q1 2018
# 27      Q1 2018
# 28      Q1 2018
# 29      Q1 2018
# 30      Q1 2018
# 31      Q1 2018
# 32      Q1 2018
# 33      Q1 2018
# 34      Q1 2018
# 35      Q1 2018
# 36      Q1 2018
# 37      Q1 2018
# 38      Q1 2018
# 39      Q1 2018
# 40      Q1 2018
# 41      Q1 2018
# 42      Q1 2018
# 43      Q1 2018
# 44      Q1 2018
# 45      Q1 2018
# 46      Q1 2018
# 47      Q1 2018
# 48      Q1 2018
# 49      Q1 2018
# 50      Q1 2018
# 51      Q1 2018
# 52      Q1 2018
# 53      Q1 2018
# 54      Q1 2018
# ...

# %%
print(sales_products_data['Quarter'])
# Out:
# 0       Q1 2018
# 1       Q1 2018
# 2       Q1 2018
# 3       Q1 2018
# 4       Q1 2018
# 5       Q1 2018
# 6       Q1 2018
# 7       Q1 2018
# 8       Q1 2018
# 9       Q1 2018
# 10      Q1 2018
# 11      Q1 2018
# 12      Q1 2018
# 13      Q1 2018
# 14      Q1 2018
# 15      Q1 2018
# 16      Q1 2018
# 17      Q1 2018
# 18      Q1 2018
# 19      Q1 2018
# 20      Q1 2018
# 21      Q1 2018
# 22      Q1 2018
# 23      Q1 2018
# 24      Q1 2018
# 25      Q1 2018
# 26      Q1 2018
# 27      Q1 2018
# 28      Q1 2018
# 29      Q1 2018
# 30      Q1 2018
# 31      Q1 2018
# 32      Q1 2018
# 33      Q1 2018
# 34      Q1 2018
# 35      Q1 2018
# 36      Q1 2018
# 37      Q1 2018
# 38      Q1 2018
# 39      Q1 2018
# 40      Q1 2018
# 41      Q1 2018
# 42      Q1 2018
# 43      Q1 2018
# 44      Q1 2018
# 45      Q1 2018
# 46      Q1 2018
# 47      Q1 2018
# 48      Q1 2018
# 49      Q1 2018
# 50      Q1 2018
# 51      Q1 2018
# 52      Q1 2018
# 53      Q1 2018
# 54      Q1 2018
# ...

# %%
print(type(sales_products_data["Quarter"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(sales_products_data['Revenue'].dtypes)
# Out:
# float64

# %%
print(sales_products_data[["Revenue", "Quantity"]].head(5))
# Out:
#     Revenue  Quantity
# 0  59728.66     491.0
# 1  36050.32     254.0
# 2  90040.48     149.0
# 3       NaN     305.0
# 4       NaN     182.0

# %%
column_names = ['Revenue', 'Quantity']
print(sales_products_data[column_names].head(5))
# Out:
#     Revenue  Quantity
# 0  59728.66     491.0
# 1  36050.32     254.0
# 2  90040.48     149.0
# 3       NaN     305.0
# 4       NaN     182.0

# %%
print(sales_products_data.iloc[0])
# Out:
# SaleID                              SaleID_1
# RetailerCountry                United States
# OrderMethod                              Fax
# RetailerType                   Outdoors Shop
# ProductLine             Personal Accessories
# ProductType                     Cooking Gear
# Product            TrailChef Deluxe Cook Set
# Year                                  2018.0
# Quarter                              Q1 2018
# Revenue                             59728.66
# Quantity                               491.0
# GrossMargin                         0.357548
# Name: 0, dtype: object

# %%
print(sales_products_data.iloc[-2])
# Out:
# SaleID                      SaleID_1275
# RetailerCountry                   Spain
# OrderMethod                 Sales visit
# RetailerType              Outdoors Shop
# ProductLine        Personal Accessories
# ProductType                       Tools
# Product                     Granite Axe
# Year                             2020.0
# Quarter                         Q3 2020
# Revenue                         56499.0
# Quantity                         1472.0
# GrossMargin                    0.490667
# Name: 1274, dtype: object

# %%
sales_products_data.ProductType[1]
# Out:
# 'Cooking Gear'

# %%
sales_products_data.iloc[1, 5]
# Out:
# 'Cooking Gear'

# %%
print(sales_products_data.iloc[(sales_products_data.shape[0]-1), (sales_products_data.shape[1]-1)])
# Out:
# 0.38689474

# %%
sales_products_data.Product.iloc[0]
# Out:
# 'TrailChef Deluxe Cook Set'

# %%
sales_products_data = sales_products_data.set_index('SaleID')

# %%
sales_products_data.head(5)
# Out:
#             RetailerCountry  OrderMethod       RetailerType               ProductLine           ProductType                            Product    Year  Quarter    Revenue  Quantity  GrossMargin
# SaleID
# SaleID_1      United States          Fax      Outdoors Shop      Personal Accessories          Cooking Gear          TrailChef Deluxe Cook Set  2018.0  Q1 2018   59728.66     491.0     0.357548
# SaleID_2      United States          Fax      Outdoors Shop          Sports Equipment          Cooking Gear             TrailChef Double Flame  2018.0  Q1 2018   36050.32     254.0     0.484274
# SaleID_3      United States          Fax      Outdoors Shop                       NaN                 Tents                          Star Dome  2018.0  Q1 2018   90040.48     149.0          NaN
# SaleID_4      United States          Fax      Outdoors Shop                       NaN                 Tents                       Star Gazer 2  2018.0  Q1 2018        NaN     305.0     0.292938
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 2000)

data = pd.read_csv('Sales-products-100.csv', index_col='SaleID')
sales_products_data = data.copy()
sales_products_data.head(5)
# Out:
#          RetailerCountry OrderMethod   RetailerType           ProductLine   ProductType                    Product    Year  Quarter   Revenue  Quantity  GrossMargin
# SaleID
# SaleID_1   United States         Fax  Outdoors Shop  Personal Accessories  Cooking Gear  TrailChef Deluxe Cook Set  2018.0  Q1 2018  59728.66     491.0     0.357548
# SaleID_2   United States         Fax  Outdoors Shop      Sports Equipment  Cooking Gear     TrailChef Double Flame  2018.0  Q1 2018  36050.32     254.0     0.484274
# SaleID_3   United States         Fax  Outdoors Shop                   NaN         Tents                  Star Dome  2018.0  Q1 2018  90040.48     149.0          NaN
# SaleID_4   United States         Fax  Outdoors Shop                   NaN         Tents               Star Gazer 2  2018.0  Q1 2018       NaN     305.0     0.292938
# ...

# %%
sales_products_data.loc['SaleID_1']
# Out:
# RetailerCountry                United States
# OrderMethod                              Fax
# RetailerType                   Outdoors Shop
# ProductLine             Personal Accessories
# ProductType                     Cooking Gear
# Product            TrailChef Deluxe Cook Set
# Year                                  2018.0
# Quarter                              Q1 2018
# Revenue                             59728.66
# Quantity                               491.0
# GrossMargin                         0.357548
# Name: SaleID_1, dtype: object

# %%
sales_products_data.GrossMargin.loc['SaleID_4']
# Out:
# 0.29293788

# %%
sales_products_data.loc['SaleID_4'].GrossMargin
# Out:
# 0.29293788

# %%
sales_products_data.loc[['SaleID_15','SaleID_35','SaleID_97']]
# Out:
#           RetailerCountry OrderMethod   RetailerType           ProductLine ProductType   Product    Year  Quarter  Revenue  Quantity  GrossMargin
# SaleID
# SaleID_15   United States         Web           Mall  Personal Accessories     Eyewear  Hawk Eye  2018.0  Q1 2018  29584.0     730.0     0.410535
# SaleID_35          Canada         Fax  Outdoors Shop     Camping Equipment     Watches    Legend  2018.0  Q1 2018   3840.0      19.0     0.483455
# SaleID_97         Austria         Web   Sports Store      Sports Equipment     Watches     Venue  2018.0  Q2 2018  81422.0    1116.0     0.423624

# %%
sales_products_data.loc[:, 'Year'].tail()
# Out:
# SaleID
# SaleID_1272    2020.0
# SaleID_1273    2020.0
# SaleID_1274    2020.0
# SaleID_1275    2020.0
# SaleID_1276    2020.0
# Name: Year, dtype: float64

# %%
sales_products_data.head(5)
# Out:
#          RetailerCountry OrderMethod   RetailerType           ProductLine   ProductType                    Product    Year  Quarter   Revenue  Quantity  GrossMargin
# SaleID
# SaleID_1   United States         Fax  Outdoors Shop  Personal Accessories  Cooking Gear  TrailChef Deluxe Cook Set  2018.0  Q1 2018  59728.66     491.0     0.357548
# SaleID_2   United States         Fax  Outdoors Shop      Sports Equipment  Cooking Gear     TrailChef Double Flame  2018.0  Q1 2018  36050.32     254.0     0.484274
# SaleID_3   United States         Fax  Outdoors Shop                   NaN         Tents                  Star Dome  2018.0  Q1 2018  90040.48     149.0          NaN
# SaleID_4   United States         Fax  Outdoors Shop                   NaN         Tents               Star Gazer 2  2018.0  Q1 2018       NaN     305.0     0.292938
# ...

# %%
sales_products_data.GrossMargin.head(5)
# Out:
# SaleID
# SaleID_1    0.357548
# SaleID_2    0.484274
# SaleID_3         NaN
# SaleID_4    0.292938
# SaleID_5    0.610710
# Name: GrossMargin, dtype: float64

# %%
sales_products_data.loc[:, 'GrossMargin'].head(5)
# Out:
# SaleID
# SaleID_1    0.357548
# SaleID_2    0.484274
# SaleID_3         NaN
# SaleID_4    0.292938
# SaleID_5    0.610710
# Name: GrossMargin, dtype: float64

# %%
sales_products_data.iloc[[9, 14]].loc[:, 'OrderMethod']
# Out:
# SaleID
# SaleID_10    Mail
# SaleID_15     Web
# Name: OrderMethod, dtype: object

# %%
sales_products_data.loc[:, 'OrderMethod'].iloc[[9, 14]]
# Out:
# SaleID
# SaleID_10    Mail
# SaleID_15     Web
# Name: OrderMethod, dtype: object

# %%
sales_products_data.head()
# Out:
#          RetailerCountry OrderMethod   RetailerType           ProductLine   ProductType                    Product    Year  Quarter   Revenue  Quantity  GrossMargin
# SaleID
# SaleID_1   United States         Fax  Outdoors Shop  Personal Accessories  Cooking Gear  TrailChef Deluxe Cook Set  2018.0  Q1 2018  59728.66     491.0     0.357548
# SaleID_2   United States         Fax  Outdoors Shop      Sports Equipment  Cooking Gear     TrailChef Double Flame  2018.0  Q1 2018  36050.32     254.0     0.484274
# SaleID_3   United States         Fax  Outdoors Shop                   NaN         Tents                  Star Dome  2018.0  Q1 2018  90040.48     149.0          NaN
# SaleID_4   United States         Fax  Outdoors Shop                   NaN         Tents               Star Gazer 2  2018.0  Q1 2018       NaN     305.0     0.292938
# ...

# %%
sales_products_data.iloc[:, [1,2]]
# Out:
#              OrderMethod       RetailerType
# SaleID
# SaleID_1             Fax      Outdoors Shop
# SaleID_2             Fax      Outdoors Shop
# SaleID_3             Fax      Outdoors Shop
# SaleID_4             Fax      Outdoors Shop
# SaleID_5             NaN      Outdoors Shop
# SaleID_6             Fax      Outdoors Shop
# SaleID_7           Phone               Mall
# SaleID_8           Phone               Mall
# SaleID_9           Phone               Mall
# SaleID_10           Mail   Department Store
# SaleID_11           Mail   Department Store
# SaleID_12           Mail   Department Store
# SaleID_13            Web               Mall
# SaleID_14            Web               Mall
# SaleID_15            Web               Mall
# SaleID_16            Web               Mall
# SaleID_17            Web               Mall
# SaleID_18            Web               Mall
# SaleID_19            Web      Outdoors Shop
# SaleID_20    Sales visit      Outdoors Shop
# ...

# %%
sales_products_data.loc['SaleID_1'].loc['OrderMethod']
# Out:
# 'Fax'

# %%
sales_products_data.loc[['SaleID_50','SaleID_87']]
# Out:
#           RetailerCountry OrderMethod  RetailerType               ProductLine ProductType    Product    Year  Quarter   Revenue  Quantity  GrossMargin
# SaleID
# SaleID_50          Canada         Web  Sports Store  Mountaineering Equipment  Binoculars  Seeker 50  2018.0  Q1 2018  11067.22      89.0     0.275588
# SaleID_87         Austria         Web  Sports Store      Personal Accessories       Tents   Star Peg  2018.0  Q2 2018   3325.94    1599.0          NaN
